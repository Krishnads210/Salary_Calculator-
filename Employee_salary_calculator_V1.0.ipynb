# %%
employees = {
    "emp1": {"name": "Krishna", "salary_per_day": 1500, "days_present": 24, "late_days": 3},
    "emp2": {"name": "Anil",    "salary_per_day": 1200, "days_present": 26, "late_days": 0},
    "emp3": {"name": "Sravani", "salary_per_day": 1800, "days_present": 22, "late_days": 5},
    "emp4": {"name": "Meera",   "salary_per_day": 2000, "days_present": 25, "late_days": 1},
    "emp5": {"name": "Rahul",   "salary_per_day": 1350, "days_present": 20, "late_days": 4},
}

# %%
emp_id = input("Please enter employee id:")
name = input("Please enter employee name:")
salary_per_day = input("Please enter employee salary per day:")
days_present = input("Please enter the no. of days the employee was present:")
late_days = input("Please enter the no. of days the employee was late:")

# %%
if emp_id not in employees.keys():
    employees[emp_id] = {"name": name,"salary_per_day": int(salary_per_day),"days_present": int(days_present),"late_days": int(late_days)}
else:
    print(emp_id + "ID already exists")

# %%
employees
# Out:
# {'emp1': {'name': 'Krishna',
#   'salary_per_day': 1500,
#   'days_present': 24,
#   'late_days': 3},
#  'emp2': {'name': 'Anil',
#   'salary_per_day': 1200,
#   'days_present': 26,
#   'late_days': 0},
#  'emp3': {'name': 'Sravani',
#   'salary_per_day': 1800,
#   'days_present': 22,
#   'late_days': 5},
#  'emp4': {'name': 'Meera',
#   'salary_per_day': 2000,
#   'days_present': 25,
#   'late_days': 1},
#  'emp5': {'name': 'Rahul',
#   'salary_per_day': 1350,
#   'days_present': 20,
#   'late_days': 4},
#  'emp6': {'name': 'Krishna Murthy',
#   'salary_per_day': 3000,
#   'days_present': 24,
#   'late_days': 0}}

# %%
employees.keys()
# Out:
# dict_keys(['emp1', 'emp2', 'emp3', 'emp4', 'emp5', 'emp6'])

# %%
employees.values()
# Out:
# dict_values([{'name': 'Krishna', 'salary_per_day': 1500, 'days_present': 24, 'late_days': 3}, {'name': 'Anil', 'salary_per_day': 1200, 'days_present': 26, 'late_days': 0}, {'name': 'Sravani', 'salary_per_day': 1800, 'days_present': 22, 'late_days': 5}, {'name': 'Meera', 'salary_per_day': 2000, 'days_present': 25, 'late_days': 1}, {'name': 'Rahul', 'salary_per_day': 1350, 'days_present': 20, 'late_days': 4}, {'name': 'Krishna Murthy', 'salary_per_day': 3000, 'days_present': 24, 'late_days': 0}])

# %%
for i in employees.values():
    i['Gross_salary'] = i['salary_per_day']*i['days_present']
    if i['late_days'] >= 0 and i['late_days'] <= 2:
        i['Deductions'] = 0
    elif i['late_days'] >= 3 and i['late_days'] <= 5:
        i['Deductions'] = 0.05*i['salary_per_day']*i['days_present']
    elif i['late_days'] >= 6 and i['late_days'] <= 10:
        i['Deductions'] = 0.1*i['salary_per_day']*i['days_present']
    elif i['late_days'] > 10:
        i['Deductions'] = 0.2*i['salary_per_day']*i['days_present']
    i['final_salary'] = i['Gross_salary']- i['Deductions']

# %%
employees
# Out:
# {'emp1': {'name': 'Krishna',
#   'salary_per_day': 1500,
#   'days_present': 24,
#   'late_days': 3,
#   'Gross_salary': 36000,
#   'Deductions': 1800.0,
#   'final_salary': 34200.0},
#  'emp2': {'name': 'Anil',
#   'salary_per_day': 1200,
#   'days_present': 26,
#   'late_days': 0,
#   'Gross_salary': 31200,
#   'Deductions': 0,
#   'final_salary': 31200},
#  'emp3': {'name': 'Sravani',
#   'salary_per_day': 1800,
#   'days_present': 22,
#   'late_days': 5,
#   'Gross_salary': 39600,
#   'Deductions': 1980.0,
#   'final_salary': 37620.0},
#  'emp4': {'name': 'Meera',
#   'salary_per_day': 2000,
#   'days_present': 25,
#   'late_days': 1,
#   'Gross_salary': 50000,
#   'Deductions': 0,
#   'final_salary': 50000},
#  'emp5': {'name': 'Rahul',
#   'salary_per_day': 1350,
#   'days_present': 20,
#   'late_days': 4,
#   'Gross_salary': 27000,
#   'Deductions': 1350.0,
#   'final_salary': 25650.0},
#  'emp6': {'name': 'Krishna Murthy',
#   'salary_per_day': 3000,
#   'days_present': 24,
#   'late_days': 0,
#   'Gross_salary': 72000,
#   'Deductions': 0,
#   'final_salary': 72000}}

# %%
Salaries = []

for i in employees.values():
    Salaries.append(i['final_salary'])
    Highest_salary = sorted(Salaries)[-1]
    Lowest_salary = sorted(Salaries)[0]
    Total_company_payroll = sum(Salaries)

print(Salaries)
print(Highest_salary)
print(Lowest_salary)
print(Total_company_payroll)
# Out:
# [42750.0, 36000, 51300.0, 60000, 38475.0, 90000]
# 90000
# 36000
# 318525.0

# %%
Highest_salary_employee = []
for i in employees.values():
    if i['Gross_salary'] == Highest_salary:
        Highest_salary_employee.extend([(i['name'],i['Gross_salary'])])
print(Highest_salary_employee)
# Out:
# [('Krishna', 90000)]
